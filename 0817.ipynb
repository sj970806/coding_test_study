# %% [markdown]
# # 문제 1
# - H-index
# - https://school.programmers.co.kr/learn/courses/30/lessons/42747

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(citations):
    citations.sort(reverse = True)
    print(citations)
    
    answer = 0
    for i, each in enumerate(citations):
        if (i+1) > each: # i+1 : each번 이상 인용된 갯수, each : h번 인용된 논문
            return answer
        else:
            answer = (i+1)
    
    return answer

# %% [markdown]
# # 문제 2
# - N-Queen
# - https://www.acmicpc.net/problem/9663

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 풀이 참고
# - https://seongonion.tistory.com/103

# %%
n = int(input())
board = [0]*n
ans = 0

def check(x): 
    for i in range(x): # 같은 열에 있거나, 대각선에 존재하면 놓지 못함
        if board[x] == board[i] or abs(x-i) == abs(board[x] - board[i]):
            return False 
    return True

def n_queen(x):
    global ans
    if x == n:
        ans += 1
        return
    else:
        for i in range(n):
            board[x] = i 
            if check(x):
                n_queen(x+1)

n_queen(0)
print(ans)
# Out:
# 8
# 92
